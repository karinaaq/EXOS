# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
T1 = pd.read_csv('Material/T1_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T1)
plt.show()

# %%
T2 = pd.read_csv('Material/T2_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T2)
plt.show()

# %%
T3 = pd.read_csv('Material/T3_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T3)
plt.show()

# %%
T4 = pd.read_csv('Material/T4_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T4)
plt.show()

# %%
T5 = pd.read_csv('Material/T5_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T5)
plt.show()

# %%
T6 = pd.read_csv('Material/T6_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T6)
plt.show()

# %%
T7 = pd.read_csv('Material/T7_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T7)
plt.show()

# %%
T8 = pd.read_csv('Material/T8_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T8)
plt.show()

# %%
T9 = pd.read_csv('Material/T9_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T9)
plt.show()

# %%
T10 = pd.read_csv('Material/T10_SubirEscaleras.csv', usecols=[1,2], engine='python')
plt.plot(T10)
plt.show()

# %%
T11 = pd.read_csv('Material/T1_PararSentar.csv', usecols=[1,2], engine='python')
plt.plot(T11)
plt.show()

# %%
T12 = pd.read_csv('Material/T2_PararSentar.csv', usecols=[1,2], engine='python')
plt.plot(T12)
plt.show()
